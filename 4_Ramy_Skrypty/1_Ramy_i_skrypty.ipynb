# %% [markdown]
# # Laboratorium: Implementacja Ram i Skryptów w Pythonie
#
# ## Cel zadania
#
# Celem tego laboratorium jest zaimplementowanie systemu reprezentującego wiedzę o wizycie w restauracji przy użyciu ram i skryptów.
#
# ## Wprowadzenie teoretyczne
#
# ### Ramy (Frames)
# Ramy to struktury reprezentujące wiedzę na temat powtarzalnych sytuacji lub konceptów. W ramie określone są podstawowe elementy (tzw. sloty), które charakteryzują daną sytuację, oraz ich wartości.
#
# ### Skrypty (Scripts)
# Skrypty to szczególny rodzaj ram, który opisuje typowy ciąg zdarzeń, czyli sekwencję kroków, które zazwyczaj mają miejsce w danej sytuacji.
#
# ## Zadanie
#
# 1. Zdefiniuj klasę `Frame` reprezentującą ramę "wizyta w restauracji".
# 2. Zaimplementuj klasę `Script` reprezentującą skrypt "wizyta w restauracji".
# 3. Stwórz metody do wypełniania ram konkretnymi danymi.
# 4. Zaimplementuj metodę wykonującą skrypt krok po kroku.
# 5. Dodaj możliwość wyświetlania zawartości ramy i kroków skryptu.

# %%
class Frame:
    def __init__(self, name):
        self.name = name
        self.slots = {}

    def add_slot(self, slot_name, value):
        # Dodaj implementację
        pass

    def get_slot(self, slot_name):
        # Dodaj implementację
        pass

    def display(self):
        # Dodaj implementację
        pass

class Script:
    def __init__(self, name):
        self.name = name
        self.steps = []

    def add_step(self, step):
        # Dodaj implementację
        pass

    def execute(self):
        # Dodaj implementację
        pass

    def display(self):
        # Dodaj implementację
        pass

# Przykładowe użycie:
restaurant_visit = Frame("Wizyta w restauracji")
restaurant_visit.add_slot("kelner", "Anna")
restaurant_visit.add_slot("menu", ["Pizza", "Spaghetti", "Sałatka"])
restaurant_visit.add_slot("zamówienie", "Pizza")
restaurant_visit.add_slot("rachunek", 30)

restaurant_script = Script("Wizyta w restauracji")
restaurant_script.add_step("Wejście do restauracji")
restaurant_script.add_step("Odebranie menu")
restaurant_script.add_step("Złożenie zamówienia")
restaurant_script.add_step("Oczekiwanie na jedzenie")
restaurant_script.add_step("Konsumpcja posiłku")
restaurant_script.add_step("Zapłata rachunku")

# %% [markdown]
# ## Zadania do wykonania
#
# 1. Uzupełnij implementację metod w klasach `Frame` i `Script`.
# 2. Stwórz metodę w klasie `Script`, która będzie wykonywać skrypt krok po kroku, wyświetlając każdy krok i czekając na potwierdzenie użytkownika przed przejściem dalej.
# 3. Dodaj możliwość modyfikacji ramy w trakcie wykonywania skryptu (np. zmiana kelnera lub dodanie nowej pozycji do zamówienia).
# 4. Zaimplementuj prosty system wnioskowania, który na podstawie zawartości ramy będzie sugerował kolejne kroki (np. jeśli rachunek jest wysoki, zasugeruj pozostawienie napiwku).
#
# ## Rozszerzenie (dla chętnych)
#
# 5. Stwórz system, który pozwoli na definiowanie różnych ram i skryptów, a następnie będzie je łączył w bardziej złożone scenariusze (np. "wyjście do restauracji" może zawierać "rezerwację stolika" i "podróż do restauracji").
#
# ## Dyskusja
#
# Po wykonaniu zadań, zastanów się nad następującymi pytaniami:
#
# 1. Jak ramy pomagają w organizacji wiedzy o powtarzalnych sytuacjach?
# 2. Jakie są korzyści stosowania skryptów w systemach dialogowych?
# 3. Jakie są wyzwania związane z tworzeniem skryptów dla nietypowych lub złożonych sytuacji?
# 4. W jaki sposób analiza tekstu z użyciem ram i skryptów może wspierać systemy AI?
