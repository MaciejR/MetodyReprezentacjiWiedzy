# %% [markdown]
# ## Zadanie: System ekspercki do diagnozy problemów z komputerem
#
# Celem zadania jest stworzenie prostego systemu eksperckiego, który pomoże zdiagnozować typowe problemy z komputerem na podstawie objawów zgłaszanych przez użytkownika.
#
# ### Opis systemu:
#
# System będzie przeprowadzał wywiad z użytkownikiem dotyczący obserwowanych problemów z komputerem. Na podstawie uzyskanych odpowiedzi system zaproponuje możliwe przyczyny problemu oraz zalecane działania naprawcze.
#
# ### Kroki do wykonania:
#
# 1. Zdefiniuj bazę wiedzy zawierającą reguły łączące objawy z potencjalnymi problemami sprzętowymi i programowymi.
# 2. Stwórz mechanizm wnioskowania w przód (forward chaining) do przetwarzania reguł i faktów.
# 3. Zaimplementuj interaktywny interfejs użytkownika zadający pytania diagnostyczne.
# 4. Stwórz system punktacji pewności dla różnych diagnoz.
# 5. Dodaj możliwość sugerowania rozwiązań dla zdiagnozowanych problemów.
# 6. Zaimplementuj system wyjaśniający tok rozumowania (why? how?)
#
# ### Przykładowe obszary diagnostyki:
# - Problemy z uruchamianiem systemu
# - Problemy z wydajnością
# - Problemy z połączeniem internetowym
# - Problemy z dyskiem twardym
# - Problemy z przegrzewaniem
#
# ### Wymagane funkcjonalności:
# - Wielopoziomowe drzewo decyzyjne
# - System wag dla różnych symptomów
# - Możliwość cofania odpowiedzi
# - Generowanie raportu z diagnostyki

# %%
class Rule:
    def __init__(self, conditions, conclusion, certainty=1.0):
        self.conditions = conditions  # lista warunków
        self.conclusion = conclusion  # wniosek
        self.certainty = certainty    # współczynnik pewności

    def evaluate(self, facts):
        # Zaimplementuj ocenę reguły
        pass

class ExpertSystem:
    def __init__(self):
        self.rules = []
        self.facts = set()
        self.certainties = {}
        self.explanations = {}

    def add_rule(self, rule):
        # Dodaj regułę do systemu
        pass

    def add_fact(self, fact, certainty=1.0):
        # Dodaj fakt z określonym współczynnikiem pewności
        pass

    def forward_chain(self):
        # Zaimplementuj wnioskowanie w przód
        pass

    def why(self, conclusion):
        # Wyjaśnij, dlaczego system doszedł do danego wniosku
        pass

    def how(self, fact):
        # Wyjaśnij, jak dany fakt został ustalony
        pass

# Przykładowe reguły
rules = [
    Rule(['komputer nie włącza się', 'brak dźwięku przy starcie'], 
         'problem z zasilaczem', 0.8),
    Rule(['komputer włącza się', 'działa wolno', 'wysoka temperatura'], 
         'problem z chłodzeniem', 0.9),
    # Dodaj więcej reguł
]

# Inicjalizacja systemu
pc_expert = ExpertSystem()

# Funkcja do interakcji z użytkownikiem
def diagnose_computer():
    print('Witaj w systemie diagnostyki komputera.')
    print('Odpowiedz na pytania, aby otrzymać diagnozę problemu.')
    
    # Zaimplementuj logikę zadawania pytań i zbierania odpowiedzi
    
    # Generowanie diagnozy
    
    # Wyświetlanie wyników
    
# Uruchomienie systemu diagnostycznego
if __name__ == '__main__':
    diagnose_computer()
