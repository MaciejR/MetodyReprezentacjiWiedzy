# %% [markdown]
# # Zadanie: Implementacja prostej ontologii w Pythonie
#
# ## Cel zadania
#
# Celem tego zadania jest stworzenie prostej implementacji ontologii w Pythonie, wykorzystując bibliotekę `owlready2`. Ontologia to formalna reprezentacja wiedzy w danej dziedzinie, składająca się z konceptów, ich właściwości i relacji między nimi.
#
# ## Opis zadania
#
# Zaimplementuj ontologię reprezentującą wiedzę o uniwersytecie. Ontologia powinna zawierać:
#
# 1. Klasy reprezentujące główne koncepty (np. Osoba, Student, Wykładowca, Kurs)
# 2. Właściwości obiektowe (relacje między klasami)
# 3. Właściwości danych (atrybuty klas)
# 4. Instancje klas
# 5. Proste reguły wnioskowania
#
# ## Wymagania
#
# 1. Użyj biblioteki `owlready2` do implementacji ontologii.
# 2. Stwórz co najmniej 4 klasy w ontologii.
# 3. Zdefiniuj co najmniej 2 właściwości obiektowe i 2 właściwości danych.
# 4. Utwórz kilka instancji dla każdej klasy.
# 5. Zaimplementuj co najmniej jedną regułę wnioskowania.
# 6. Napisz funkcję do przeszukiwania ontologii i wyświetlania informacji.
#
# ## Przykładowy kod startowy
#
# ```python
# from owlready2 import *
#
# # Tworzenie ontologii
# onto = get_ontology("http://example.org/university.owl")
#
# with onto:
#     class Person(Thing):
#         pass
#
#     class Student(Person):
#         pass
#
#     class Lecturer(Person):
#         pass
#
#     class Course(Thing):
#         pass
#
#     # Dodaj właściwości i reguły tutaj
#
# # Tworzenie instancji
# with onto:
#     student1 = Student("student1")
#     lecturer1 = Lecturer("lecturer1")
#     course1 = Course("course1")
#
# # Funkcja do przeszukiwania ontologii
# def search_ontology(onto):
#     # Implementacja przeszukiwania
#     pass
#
# # Wywołanie funkcji przeszukującej
# search_ontology(onto)
# ```
#
# ## Rozszerzenia (dla chętnych)
#
# 1. Dodaj bardziej złożone reguły wnioskowania.
# 2. Zaimplementuj funkcję do wizualizacji ontologii.
# 3. Rozszerz ontologię o dodatkowe klasy i relacje (np. Wydział, Egzamin).
# 4. Dodaj możliwość wczytywania i zapisywania ontologii do pliku OWL.
#
# Powodzenia!

# %%
# Tutaj możesz rozpocząć implementację
from owlready2 import *

# Tworzenie ontologii
onto = get_ontology("http://example.org/university.owl")

# Implementacja klas, właściwości i reguł

# Tworzenie instancji

# Funkcja do przeszukiwania ontologii

# Testowanie ontologii
