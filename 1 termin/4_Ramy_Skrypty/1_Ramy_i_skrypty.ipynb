# %% [markdown]
# # Laboratorium: Implementacja Ram i Skryptów dla Zakupów Online
#
# ## Cel zadania
#
# Celem laboratorium jest zaimplementowanie systemu reprezentującego wiedzę o procesie zakupów w sklepie internetowym przy użyciu ram i skryptów.
#
# ## Wprowadzenie teoretyczne
#
# ### Ramy (Frames)
# Ramy to struktury danych reprezentujące stereotypowe sytuacje lub obiekty. Każda rama zawiera zestaw atrybutów (slotów) opisujących dany koncept i jego właściwości.
#
# ### Skrypty (Scripts)
# Skrypty reprezentują typowe sekwencje zdarzeń w określonych sytuacjach, definiując standardowy przebieg procesu krok po kroku.
#
# ## Zadanie
#
# 1. Zdefiniuj klasę `Frame` reprezentującą ramę "zakupy online".
# 2. Zaimplementuj klasę `Script` reprezentującą skrypt "proces zakupów online".
# 3. Stwórz metody do zarządzania zawartością koszyka zakupowego.
# 4. Zaimplementuj obsługę procesu zamówienia i płatności.
# 5. Dodaj system powiadomień o statusie zamówienia.

# %%
class Frame:
    def __init__(self, name):
        self.name = name
        self.slots = {}

    def add_slot(self, slot_name, value):
        # Implementacja dodawania slotu
        pass

    def update_slot(self, slot_name, value):
        # Implementacja aktualizacji slotu
        pass

    def get_slot(self, slot_name):
        # Implementacja pobierania wartości slotu
        pass

    def display(self):
        # Implementacja wyświetlania zawartości ramy
        pass

class Script:
    def __init__(self, name):
        self.name = name
        self.steps = []
        self.current_step = 0

    def add_step(self, step_description, action=None):
        # Implementacja dodawania kroku
        pass

    def execute_step(self):
        # Implementacja wykonania pojedynczego kroku
        pass

    def execute_all(self):
        # Implementacja wykonania całego skryptu
        pass

    def display_progress(self):
        # Implementacja wyświetlania postępu
        pass

# %% [markdown]
# ## Zadania do wykonania
#
# ### Zadanie 1: Implementacja podstawowych funkcjonalności
#
# 1. Uzupełnij implementację metod w klasach `Frame` i `Script`.
# 2. Stwórz ramę `OnlineShopFrame` z następującymi slotami:
#    - koszyk (lista produktów)
#    - dane_klienta (słownik z informacjami)
#    - metoda_platnosci
#    - status_zamowienia
#    - numer_zamowienia
# 3. Zaimplementuj skrypt `ShoppingScript` z krokami:
#    - przeglądanie produktów
#    - dodawanie do koszyka
#    - wprowadzanie danych
#    - wybór płatności
#    - potwierdzenie zamówienia
#
# ### Zadanie 2: Rozszerzenie funkcjonalności
#
# 1. Dodaj obsługę wyjątków w skrypcie (np. brak produktu, błąd płatności).
# 2. Zaimplementuj system walidacji danych klienta.
# 3. Stwórz mechanizm śledzenia statusu zamówienia.
# 4. Dodaj możliwość modyfikacji koszyka w trakcie zakupów.
#
# ### Zadanie 3: Implementacja logiki biznesowej
#
# 1. Dodaj system rabatów (np. przy zakupach powyżej określonej kwoty).
# 2. Zaimplementuj obsługę kodów promocyjnych.
# 3. Stwórz system rekomendacji produktów.
# 4. Dodaj obsługę różnych metod dostawy.
#
# ## Rozszerzenia (dla chętnych)
#
# 1. Zaimplementuj system obsługi zwrotów i reklamacji.
# 2. Dodaj system lojalnościowy z punktami za zakupy.
# 3. Stwórz mechanizm zapisywania historii zakupów.
# 4. Zaimplementuj system powiadomień email/SMS.
#
# ## Pytania do dyskusji
#
# 1. Jakie są zalety używania ram i skryptów w modelowaniu procesów biznesowych?
# 2. W jaki sposób można obsłużyć nietypowe scenariusze zakupowe?
# 3. Jak efektywnie połączyć system ram i skryptów z bazą danych?
# 4. Jakie są wyzwania związane z implementacją systemu płatności?
# 5. Jak można wykorzystać ramy i skrypty do personalizacji doświadczenia zakupowego?
